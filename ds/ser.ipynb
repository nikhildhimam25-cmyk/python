# %%
# !pip install pandas

# %%
import pandas as pd

# %%
ser = pd.Series([10,20,30,40,50,60,70])
ser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser2 = pd.Series([10,20,30,40,50,60,70], index=['a','b','c','d','e','f','g'])
ser2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
ser3 = pd.Series([10,20,30.33,40,50,60,70])
ser3
# Out:
# 0    10.00
# 1    20.00
# 2    30.33
# 3    40.00
# 4    50.00
# 5    60.00
# 6    70.00
# dtype: float64

# %%
ser4 = pd.Series([10,20,30.33,40,50,60,"70"])
ser4
# Out:
# 0       10
# 1       20
# 2    30.33
# 3       40
# 4       50
# 5       60
# 6       70
# dtype: object

# %%
# int < float < object

# %%
ser4.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7 entries, 0 to 6
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 7 non-null      object
# dtypes: object(1)
# memory usage: 188.0+ bytes

# %%
ser
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
ser[0]
# Out:
# 10

# %%
ser[6]
# Out:
# 70

# %%
# ser[-1]  #error

# %%
ser2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
ser2['a']
# Out:
# 10

# %%
ser2['c']
# Out:
# 30

# %%
ser2['d']
# Out:
# 40

# %%
ser2[0]
# Out:
# 10

# %%
ser2[4]
# Out:
# 50

# %%
ser5 = pd.Series([10,20,30,40,50,60,70], index=['a','b',1,'d','e',3,'g'])
ser5
# Out:
# a    10
# b    20
# 1    30
# d    40
# e    50
# 3    60
# g    70
# dtype: int64

# %%
ser5[1]
# Out:
# 30

# %%
ser5[3]
# Out:
# 60

# %%
# ser5[2]  #error

# %%
# loc and iloc

# %%
ser5
# Out:
# a    10
# b    20
# 1    30
# d    40
# e    50
# 3    60
# g    70
# dtype: int64

# %%
ser5.loc[1]
# Out:
# 30

# %%
ser5.iloc[6]
# Out:
# 70

# %%
ser5.loc[3]
# Out:
# 60

# %%
ser5.loc[['a','e']]
# Out:
# a    10
# e    50
# dtype: int64

# %%
ser5.iloc[[1,3,4]]
# Out:
# b    20
# d    40
# e    50
# dtype: int64

# %%
# at and iat

# %%
ser5.iat[1]
# ser5.iat[[1,2]] #error
# Out:
# 20

# %%
ser6 = pd.Series(range(1,21), index=range(101,121))
ser6
# Out:
# 101     1
# 102     2
# 103     3
# 104     4
# 105     5
# 106     6
# 107     7
# 108     8
# 109     9
# 110    10
# 111    11
# 112    12
# 113    13
# 114    14
# 115    15
# 116    16
# 117    17
# 118    18
# 119    19
# 120    20
# dtype: int64

# %%
ser6[ser6 > 12]
# Out:
# 113    13
# 114    14
# 115    15
# 116    16
# 117    17
# 118    18
# 119    19
# 120    20
# dtype: int64

# %%
# ser6[ser6>12 and ser6<15]
# ser6

# %%
# and --> &
# or --> |
# not --> ~ !

# %%
ser6[(ser6 > 10) & (ser6 <15)]
# Out:
# 111    11
# 112    12
# 113    13
# 114    14
# dtype: int64

# %%
# between()

# %%
ser6
# Out:
# 101     1
# 102     2
# 103     3
# 104     4
# 105     5
# 106     6
# 107     7
# 108     8
# 109     9
# 110    10
# 111    11
# 112    12
# 113    13
# 114    14
# 115    15
# 116    16
# 117    17
# 118    18
# 119    19
# 120    20
# dtype: int64

# %%
ser6[ser6.between(10,15, inclusive='neither')]
# Out:
# 111    11
# 112    12
# 113    13
# 114    14
# dtype: int64

# %%
# NaN --> Not a Number

# %%
# Fill Nan 
# Drop Nan

# %%
# fillna()
# dropna()

# %%
# None, np.nan

# %%
ser7 = pd.Series([None, 11, 23,None,7, "Hello",None,True,1,None])
ser7
# Out:
# 0     None
# 1       11
# 2       23
# 3     None
# 4        7
# 5    Hello
# 6     None
# 7     True
# 8        1
# 9     None
# dtype: object

# %%
import numpy as np

# %%
ser7 = pd.Series([np.nan, 11, 23,np.nan,7, "Hello",np.nan,True,1,np.nan])
ser7
# Out:
# 0      NaN
# 1       11
# 2       23
# 3      NaN
# 4        7
# 5    Hello
# 6      NaN
# 7     True
# 8        1
# 9      NaN
# dtype: object

# %%
# isna()
# isnull()

# %%
ser7.isna().sum()
# Out:
# 4

# %%
ser7.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 10 entries, 0 to 9
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      object
# dtypes: object(1)
# memory usage: 212.0+ bytes

# %%
ser7.isnull().sum()
# Out:
# 4

# %%
ser7.fillna(100)
# Out:
# 0      100
# 1       11
# 2       23
# 3      100
# 4        7
# 5    Hello
# 6      100
# 7     True
# 8        1
# 9      100
# dtype: object

# %%
# mean = avrage fillna
# mode -> fillna

# %%
ser8 = pd.Series([np.nan, 11, 23,np.nan,7, 78,np.nan,True,1,np.nan])
ser8
# Out:
# 0     NaN
# 1      11
# 2      23
# 3     NaN
# 4       7
# 5      78
# 6     NaN
# 7    True
# 8       1
# 9     NaN
# dtype: object

# %%
mean_val = ser8.mean()
mean_val
# Out:
# 20.166666666666668

# %%
ser8.fillna(mean_val, inplace=True)

# %%
ser8
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8.fillna(method='ffill')
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8.fillna(method='bfill')
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8.fillna(method='backfill')
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8 = ser8.fillna(method='pad')

# %%
ser8
# Out:
# 0    20.166667
# 1           11
# 2           23
# 3    20.166667
# 4            7
# 5           78
# 6    20.166667
# 7         True
# 8            1
# 9    20.166667
# dtype: object

# %%
ser8.dropna(inplace=True)

# %%
ser8
# Out:
# 1      11
# 2      23
# 4       7
# 5      78
# 7    True
# 8       1
# dtype: object

# %%
ser8.reset_index(drop=True, inplace=True)

# %%
ser8
# Out:
# 0      11
# 1      23
# 2       7
# 3      78
# 4    True
# 5       1
# dtype: object
